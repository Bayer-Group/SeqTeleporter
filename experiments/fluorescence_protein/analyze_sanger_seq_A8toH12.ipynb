# %%
from os import path
from experiments.exp_libs.exp_libs import *

here = path.dirname(path.abspath('__file__'))
# Out:
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\venv\Lib\site-packages\Bio\pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(

# %%
plate_mapper_path = path.join(here, "input_ecoli2","input_AzR_2024-09-09output","results","2024-09-09_source_destination_plate_map.xlsx")
toolbox_plasmids_path = path.join(here, "ecoli_modules_secret","T7_amp_toolbox_plasmids.gb")
seq_res_dir = path.join(here, "sequencing","results","AzR")
out_path = path.join(here, "sequencing","results")
ref_dna_name = 'AzR_T7_assembly'
filter_seq_res_by_pattern = "G02|H02"

# %%
expected_variant_seqrecords_dir = generate_expected_variant_seqrecords(plate_mapper_path, toolbox_plasmids_path)

# %%
sequencing_res_ALL486 = SequencingResSetting('ALL486', ref_dna_name)
seq_analysis_file_ALL486 = analyse_sanger_seq_res(
    seq_res_dir,
    filter_seq_res_by_pattern,
    expected_variant_seqrecords_dir,
    out_path,
    sequencing_res_ALL486.primer,
    ref_dna_name
)
sequencing_res_ALL482 = SequencingResSetting('ALL482', ref_dna_name)
seq_analysis_file_ALL482 = analyse_sanger_seq_res(
    seq_res_dir,
    filter_seq_res_by_pattern,
    expected_variant_seqrecords_dir,
    out_path,
    sequencing_res_ALL482.primer,
    ref_dna_name
)
# Out:
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL486\G02-1_Wup503-2_ALL486.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL486\G02-2_Wup503-2_ALL486.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL486\H02-1_Wup503-2_ALL486.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL486\H02-1_Wup507-2_ALL486.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL486\H02-1_Wup508-2_ALL486.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL486\H02-2_Wup503-2_ALL486.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL486\H02-2_Wup507-2_ALL486.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL486\H02-2_Wup508-2_ALL486.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL486\H02-3_Wup507-2_ALL486.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL486\H02-3_Wup508-2_ALL486.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL486\H02-4_Wup507-2_ALL486.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL486\H02-4_Wup508-2_ALL486.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL482\G02-1_Wup503-1_ALL482.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL482\G02-2_Wup503-1_ALL482.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL482\H02-1_Wup503-1_ALL482.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL482\H02-1_Wup507-1_ALL482.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL482\H02-1_Wup508-1_ALL482.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL482\H02-2_Wup503-1_ALL482.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL482\H02-2_Wup507-1_ALL482.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL482\H02-2_Wup508-1_ALL482.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL482\H02-3_Wup507-1_ALL482.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL482\H02-3_Wup508-1_ALL482.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL482\H02-4_Wup507-1_ALL482.ab1
# C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\fluorescence_protein\sequencing\results\AzR\ALL482\H02-4_Wup508-1_ALL482.ab1

# %%
validated_by_well, not_validated_by_well = validate_clones(
    seq_analysis_file_ALL482,
    seq_analysis_file_ALL486,
    sequencing_res_ALL482.primer,
    sequencing_res_ALL486.primer,
    path.join(seq_res_dir,"ALL482"),
    filter_seq_res_by_pattern,
    expected_variant_seqrecords_dir
)
validated_by_well, not_validated_by_well
# Out:
# ({'G02': set(), 'H02': {'H02-3_Wup507.ab1'}},
#  {'G02': {'G02-1_Wup503.ab1', 'G02-2_Wup503.ab1'},
#   'H02': {'H02-1_Wup503.ab1',
#    'H02-1_Wup507.ab1',
#    'H02-1_Wup508.ab1',
#    'H02-2_Wup503.ab1',
#    'H02-2_Wup507.ab1',
#    'H02-2_Wup508.ab1',
#    'H02-3_Wup508.ab1',
#    'H02-4_Wup507.ab1',
#    'H02-4_Wup508.ab1'}})

# %%
make_plate_layout(validated_by_well)
# Out:
#                    02
# G                  {}
# H  {H02-3_Wup507.ab1}
