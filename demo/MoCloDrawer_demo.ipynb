# %%
from seqteleporter.MoCloDrawer.MoCloDrawer import draw_moclo_designs_with_overlap_number


draw_moclo_designs_with_overlap_number(
    input_xlsx=r"C:\Users\GOFKV\PycharmProjects\pptransformer\design_tbls\design_positions_manual.xlsx",
    output_pptx_path=r"C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\draw_chain_designs_secret\chain_designs_figures.pptx",
    output_image_dir=r"C:\Users\GOFKV\PycharmProjects\seqTeleporter\experiments\draw_chain_designs_secret"
)
